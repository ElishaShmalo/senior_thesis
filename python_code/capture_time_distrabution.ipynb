# %% [markdown]
# # Capture time distrabution analysis

# %% [markdown]
# ---
# ## 1. Imports & Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib as mpl
from scipy.stats import linregress, poisson
from scipy.optimize import minimize_scalar
import os

def make_path_exist(filepath):
    os.makedirs(os.path.dirname(filepath), exist_ok=True)

def save_simple_dict_to_csv(data: dict, filepath: str):
    """Save {float -> scalar or list} dict to CSV."""
    make_path_exist(filepath)
    rows = []
    for k, v in sorted(data.items()):
        if hasattr(v, '__len__'):
            rows.append({"aval": k, "value": v[0], "value_err": v[1]})
        else:
            rows.append({"aval": k, "value": v})
    pd.DataFrame(rows).to_csv(filepath, index=False)


def set_default_plot_style():
    plt.style.use("default")  # start clean

    plt.rcParams["axes.grid"] = True
    plt.rcParams["grid.alpha"] = 0.2
    plt.rcParams["grid.linestyle"] = "-"
    plt.rcParams["grid.color"] = "gray"

    plt.rcParams["axes.spines.top"] = False
    plt.rcParams["axes.spines.right"] = False

    plt.rcParams["axes.linewidth"] = 1.2

    plt.rcParams["legend.frameon"] = False

    plt.rcParams["font.size"] = 27
    plt.rcParams["axes.labelsize"] = 32
    plt.rcParams["legend.fontsize"] = 21

    plt.rcParams["font.size"] = 18
    plt.rcParams["axes.labelsize"] = 24
    plt.rcParams["legend.fontsize"] = 12

    mpl.rcParams['text.usetex'] = True
    mpl.rcParams['font.family'] = 'serif'
    mpl.rcParams['font.serif'] = ['Computer Modern Roman']

# Call once at the top of your script
set_default_plot_style()
# ax = plt.gca() # color = ax._get_lines.get_next_color()

# %% [markdown]
# ---
# ## 2. Global Parameters

# %%
J   = 1
tau = 1 * J

N_val = 4

num_unit_cells_vals = [8, 16, 32, 64, 128]  # adjust as needed
# num_unit_cells_vals = [64]  # adjust as needed
num_uc = len(num_unit_cells_vals)

# Blue palette: light -> dark
blue_colors = [mcolors.to_rgba(c) for c in
               plt.cm.Blues(np.linspace(0.35, 0.85, num_uc))]

num_initial_conds = 1000

a_vals = [
    0.58, 0.6, 0.62, 0.64
]

# a_vals = [0.68, 0.69, 0.7, 0.71, 0.72, 0.74, 0.76]
# a_vals = [0.68]

z_val      = 1.7
z_val_name = str(z_val).replace(".", "p")
z_fit_val  = 1.7
z_fit_name = str(z_fit_val).replace(".", "p")

time_steps = 1

parent_data_path = "/Volumes/ExternalData"  # <- adjust as needed

# %%
# collected_S_diffs_mean[L][a_val]     = np.array of shape (n,)  -- mean over ICs
# collected_S_diff_SEMs[L][a_val] = np.array of shape (n,)  -- SEM over ICs
collected_S_diffs_mean     = {}
collected_S_diffs = {}
collected_S_diff_SEMs = {}

collected_lambda_mean     = {}
collected_lambda = {}
collected_lambda_errs = {}

for num_unit_cells in num_unit_cells_vals:
    L = num_unit_cells * N_val
    print(f"L = {L}")
    n = int(round(L ** z_fit_val))

    collected_S_diffs_mean[L]     = {}
    collected_S_diffs[L]     = {}
    collected_S_diff_SEMs[L] = {}

    collected_lambda_mean[L]     = {}
    collected_lambda[L] = {}  
    collected_lambda_errs[L] = {} 

    for a_val in a_vals:
        a_name = str(a_val).replace(".", "p")
        all_ic_diffs = []
        all_ic_lambdas = []
        print(a_val)

        for ic in range(1, num_initial_conds + 1):
            
            try:
                filepath = (
                    f"{parent_data_path}/spin_dists_per_time/N{N_val}/a{a_name}/IC1/L{L}/"
                    f"N{N_val}_a{a_name}_IC1_L{L}_z{z_val_name}_sample{ic}.csv"
                    )
                df = pd.read_csv(filepath, usecols=["delta_s", "lambda"])
            except Exception as e:
                filepath = (
                    f"{parent_data_path}/spin_dists_per_time/N{N_val}/a{a_name}/IC1/L{L}/"
                    f"N{N_val}_a{a_name}_IC1_L{L}_z1p7_sample{ic}.csv"
                    )
                df = pd.read_csv(filepath, usecols=["delta_s", "lambda"])
            diffs_vals = df["delta_s"].values[0:n:time_steps]
            lambdas_vals = df["lambda"].values[0:n:time_steps]
            all_ic_diffs.append(diffs_vals)
            all_ic_lambdas.append(lambdas_vals)
        try:
            all_ic_diffs = np.array(all_ic_diffs)
            all_ic_lambdas = np.array(all_ic_lambdas)
        except Exception as e:
            print(n//time_steps)
            for i, run in enumerate(all_ic_diffs):
                l = len(run)
                if l-1 != n//time_steps:
                    print(l, i)
        collected_S_diffs[L][a_val] = [ic_data for ic_data in all_ic_diffs]
        collected_S_diffs_mean[L][a_val]     = all_ic_diffs.mean(axis=0)
        collected_S_diff_SEMs[L][a_val] = all_ic_diffs.std(axis=0, ddof=1) / np.sqrt(num_initial_conds)

        collected_lambda_mean[L][a_val]     = all_ic_lambdas.mean(axis=0)
        collected_lambda[L][a_val] = [ic_data for ic_data in all_ic_lambdas]
        collected_lambda_errs[L][a_val] = all_ic_lambdas.std(axis=0, ddof=1) / np.sqrt(num_initial_conds)

    # Save using numpy .npz (replaces Julia's binary serialize)
    a_range = f"{min(a_vals)}_{max(a_vals)}".replace(".", "p")
    out_dir = f"data/s_diffs_for_t_star/N{N_val}/SeveralAs/IC{num_initial_conds}/L{L}/"
    os.makedirs(out_dir, exist_ok=True)
    fname = f"N{N_val}_ar{a_range}_IC{num_initial_conds}_L{L}_z{z_fit_name}"

    np.savez(out_dir + fname + "_avg.npz", **{str(a).replace(".","p"): v for a, v in collected_S_diffs_mean[L].items()})
    np.savez(out_dir + fname + "_sem.npz", **{str(a).replace(".","p"): v for a, v in collected_S_diff_SEMs[L].items()})
    print(f"  Saved: {out_dir + fname}")
# Out:
# L = 32
# 0.58
# 0.6
# 0.62
# 0.64
#   Saved: data/s_diffs_for_t_star/N4/SeveralAs/IC1000/L32/N4_ar0p58_0p64_IC1000_L32_z1p7
# L = 64
# 0.58
# 0.6
# 0.62
# 0.64
#   Saved: data/s_diffs_for_t_star/N4/SeveralAs/IC1000/L64/N4_ar0p58_0p64_IC1000_L64_z1p7
# L = 128
# 0.58
# 0.6
# 0.62
# 0.64
#   Saved: data/s_diffs_for_t_star/N4/SeveralAs/IC1000/L128/N4_ar0p58_0p64_IC1000_L128_z1p7
# L = 256
# 0.58
# 0.6
# 0.62
# 0.64
#   Saved: data/s_diffs_for_t_star/N4/SeveralAs/IC1000/L256/N4_ar0p58_0p64_IC1000_L256_z1p7
# L = 512
# 0.58
# 0.6
# 0.62
# 0.64
#   Saved: data/s_diffs_for_t_star/N4/SeveralAs/IC1000/L512/N4_ar0p58_0p64_IC1000_L512_z1p7

# %% [markdown]
# ---
# ## 5. S_diff(t) Time Traces for a Single L

# %%
# a_vals_to_plot       = [0.72, 0.73, 0.74, 0.75, 0.755, 0.76, 0.8]
num_unit_cell_plot   = 64
L_plot               = num_unit_cell_plot * N_val
n_plot               = int(round(L_plot ** z_fit_val))

fig, ax = plt.subplots(figsize=(8, 5))
ax.set_title(rf"$S_{{\mathrm{{diff}}}}$ for $N={N_val}$, $L={L_plot}$")
ax.set_xlabel(r"$t$")
ax.set_ylabel(r"$S_{\mathrm{diff}}$")

for i, a_val in enumerate(a_vals):
    y    = collected_S_diffs_mean[L_plot][a_val][:n_plot]
    yerr = collected_S_diff_SEMs[L_plot][a_val][:n_plot]
    ax.errorbar([i * time_steps for i in range(len(y))], y, yerr=yerr, label=str(a_val), capsize=0, linewidth=1)

ax.set_ylim(-0.01, 0.1)
ax.set_xlim(0, 500)
ax.legend(title="a =")
out = f"figs/delta_evolved_spins/N{N_val}/SeveralAs/IC{num_initial_conds}/L{L_plot}/S_diff_N{N_val}_L{L_plot}_z{z_val_name}.png"
make_path_exist(out)
fig.tight_layout() 
# fig.savefig(out, dpi=150)
print(f"Saved: {out}")
plt.show()
# Out:
# Saved: figs/delta_evolved_spins/N4/SeveralAs/IC2000/L256/S_diff_N4_L256_z1p7.png

# %% [markdown]
# ---
# ## 9. log(S_diff) Time Traces

# %%
# ── Propagate log errors: σ[log(y)] ≈ σ[y]/y ────────────────────────────────
collected_log_S_diff_errs = {}
for L in [n * N_val for n in num_unit_cells_vals]:
    collected_log_S_diff_errs[L] = {
        a: collected_S_diff_SEMs[L][a] / collected_S_diffs_mean[L][a]
        for a in a_vals
    }

# %% [markdown]
# ---
# ## 10. Findinf t^* using log(S_diff)
#
# For each (L, a_val), fit a line to log(S_diff) in the window `[t_min, t_max]` defined in `times_to_fit`.

# %%
L = 512
a_val = 0.62
samples = [i for i in range(20)]

ax = plt.gca() 

color = ax._get_lines.get_next_color()

ys = np.log(collected_S_diffs_mean[L][a_val])
ts = np.array([i*time_steps for i in range(len(ys))])
y_errs = np.array(collected_log_S_diff_errs[L][a_val])

ax.plot(ts, ys, c=color, marker="o", markersize=2)
ax.fill_between(ts, ys+y_errs, ys-y_errs, color=color, alpha=0.2)

x_lims = [0, 50]
ax.set_xlim(x_lims[0], x_lims[1])

mask = (ts >= x_lims[0]) & (ts <= x_lims[1])
ax.set_ylim(ys[mask].min(), ys[mask].max())

for sample in samples:
    if sample == -1:
        for series in collected_S_diffs[L][a_val]:
            ax.plot(ts, np.log(series), marker="o", markersize=2, alpha=0.5)
        break
    ax.plot(ts, np.log(collected_S_diffs[L][a_val][sample]), marker="o", markersize=2, alpha=0.5)

# %%
def find_t_star_dist(L, a_val, show_samples, time_window_size=5, dist_thresh = 1/10, error_thresh = 1, show=True):
    t_stars = []

    if show:
        ax = plt.gca() 

        color = ax._get_lines.get_next_color()

        ys = np.log(collected_S_diffs_mean[L][a_val])
        ts = np.array([i*time_steps for i in range(len(ys))])
        y_errs = np.array(collected_log_S_diff_errs[L][a_val])

        ax.plot(ts, ys, c="k", linewidth=5, alpha=0.2, label="Ensamble Avrage")
        ax.fill_between(ts, ys+y_errs, ys-y_errs, color="k", alpha=0.2)

        ax.set_xlabel("t")
        ax.set_ylabel("log(S_diff)")

    for sample, sample_data in enumerate(collected_S_diffs[L][a_val]):
        log_sample_data = np.log(np.array(sample_data))
        ts = [i*time_steps for i in range(len(log_sample_data)) if i*time_steps < L**z_val]

        ts_interp = np.arange(0, ts[-1] + 1)
        log_sample_data_interp = np.interp(ts_interp, ts, log_sample_data)

        dist = np.inf
        err = np.inf
        errs = []
        i = -1
        while dist > dist_thresh or err > error_thresh:
            i += 1
            t_window = [ts_interp[i + j] for j in range(time_window_size)]
            data_window = [log_sample_data_interp[i + j] for j in range(time_window_size)]

            (m, b), cov = np.polyfit(t_window, data_window, 1, cov=True)
            dm, db = np.sqrt(np.diag(cov))

            dist = abs((m - np.log(a_val))/(np.log(a_val)))
            err = abs(dm)

        post_t_window, post_data_window = [ts_interp[i + j] for j in range(min(500, int(L ** z_val - i - 100)))], [log_sample_data_interp[i + j] for j in range(min(500, int(L ** z_val - i - 100)))]
        pre_t_window, pre_data_window = [ts_interp[j] for j in range(max(i//2, 5))], [log_sample_data_interp[j] for j in range(max(i//2, 5))]

        (post_m, post_b) = np.polyfit(post_t_window, post_data_window, 1, cov=False)
        (pre_m, pre_b) = np.polyfit(pre_t_window, pre_data_window, 1, cov=False)

        t_stars.append(round(pre_b - post_b / (post_m - pre_m)))
    
        if show and (-1 in show_samples or sample in show_samples):
            color = ax._get_lines.get_next_color()
            
            ax.plot(ts, np.log(collected_S_diffs[L][a_val][sample]), c=color, alpha=0.5)
            ax.axvline(t_stars[sample], c=color, alpha=0.5)

            ax.plot(ts_interp, post_m*ts_interp + post_b, linestyle="--", c=color)
            ax.plot(ts_interp, pre_m*ts_interp + pre_b, linestyle="--", c=color)
            print("Test", t_stars[sample])
    if show:
        ys = np.log(collected_S_diffs_mean[L][a_val])
        ts = np.array([i*time_steps for i in range(len(ys))])
        x_lims = [0, max(t_stars)+30]
        ax.set_xlim(x_lims[0], x_lims[1])

        mask = (ts >= x_lims[0]) & (ts <= x_lims[1])
        ax.set_ylim(ys[mask].min(), ys[mask].max())
        ax.legend()
    return t_stars

find_t_star_dist(32, 0.64, [100])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 69
#      66         ax.legend()
#      67     return t_stars
# ---> 69 find_t_star_dist(32, 0.64, [100])
#
# Cell In[16], line 9, in find_t_star_dist(L, a_val, show_samples, time_window_size, dist_thresh, error_thresh, show)
#       5 ax = plt.gca()
#       7 color = ax._get_lines.get_next_color()
# ----> 9 ys = np.log(collected_S_diffs_mean[L][a_val])
#      10 ts = np.array([i*time_steps for i in range(len(ys))])
#      11 y_errs = np.array(collected_log_S_diff_errs[L][a_val])
#
# KeyError: 0.64

# %%
for L_val in np.array(num_unit_cells_vals) * N_val:

    fig, axs = plt.subplots(
        1, len(a_vals),
        figsize=(4 * len(a_vals), 4),
        sharey=True
    )

    # Handles the case where there is only one a_val
    axs = np.atleast_1d(axs)

    for ax, a_val in zip(axs, a_vals):

        t_stars = np.array(
            find_t_star_dist(L_val, a_val, [], show=False)
        )

        # Poisson fit
        lam = np.mean(t_stars)

        xs = np.arange(0, t_stars.max() + 1)
        pmf = poisson.pmf(xs, lam)

        bins = np.arange(-0.5, t_stars.max() + 1.5, 2)

        # Data
        ax.hist(
            t_stars,
            bins=bins,
            alpha=0.3,
            density=True
        )

        # Poisson fit
        # ax.plot(
        #     xs,
        #     pmf,
        #     "--",
        #     label=fr"$\lambda={lam:.3f}$"
        # )

        ax.set_title(fr"$a={a_val}$")
        ax.set_xlabel(r"$t^*$")
        ax.legend()

    axs[0].set_ylabel("Probability")
    fig.suptitle(fr"$L={L_val}$")

    plt.tight_layout()
    plt.show()
# Out:
# /var/folders/0k/n4x5z88x1rx124p1g1l55hmc0000gn/T/ipykernel_9429/3969483771.py:44: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
def poisson_fit(data):
    # empirical PMF
    counts = np.bincount(data)
    p_emp = counts / counts.sum()
    k = np.arange(len(counts))

    def loss(lam):
        p_poisson = poisson.pmf(k, lam)
        return 1-np.sum(np.sqrt(p_emp * p_poisson))

    result = minimize_scalar(
        loss,
        bounds=(1e-10, max(data) * 2),
        method="bounded"
    )

    return result.x

# %%
# a_vals = [0.62, 0.64, 0.66, 0.68]

for L_val in np.array(num_unit_cells_vals) * N_val:
    # if L_val < 128:
    #     continue
    fig, axs = plt.subplots(
        1, len(a_vals),
        figsize=(4 * len(a_vals), 4)
    )

    # Handles the case where there is only one a_val
    axs = np.atleast_1d(axs)

    for ax, a_val in zip(axs, a_vals):

        t_stars = np.array(
            find_t_star_dist(L_val, a_val, [], show=False)
        )

        # Poisson fit
        # lam = np.mean(t_stars)
        lam = poisson_fit(t_stars)

        xs = np.arange(0, t_stars.max() + 1)
        pmf = poisson.pmf(xs, lam)

        bins = np.arange(-0.5, t_stars.max() + 1.5, 1)

        ax.hist(
            t_stars,
            bins=bins,
            alpha=0.3,
            density=True
        )

        ax.plot(
            xs,
            pmf,
            "--",
            label=fr"$\mu={lam:.3f}$"
        )
        ax.set_title(rf"a = {a_val}")
        ax.legend()

    # plt.legend()
    axs[0].set_ylabel("Probability")
    fig.suptitle(fr"$L={L_val}$")

    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[93], line 17
#      12 axs = np.atleast_1d(axs)
#      14 for ax, a_val in zip(axs, a_vals):
#      16     t_stars = np.array(
# ---> 17         find_t_star_dist(L_val, a_val, [], show=False)
#      18     )
#      20     # Poisson fit
#      21     # lam = np.mean(t_stars)
#      22     lam = poisson_fit(t_stars)
#
# Cell In[16], line 35, in find_t_star_dist(L, a_val, show_samples, time_window_size, dist_thresh, error_thresh, show)
#      32 t_window = [ts_interp[i + j] for j in range(time_window_size)]
#      33 data_window = [log_sample_data_interp[i + j] for j in range(time_window_size)]
# ---> 35 (m, b), cov = np.polyfit(t_window, data_window, 1, cov=True)
#      36 dm, db = np.sqrt(np.diag(cov))
#      38 dist = abs((m - np.log(a_val))/(np.log(a_val)))
#
# ...

# %%
np.log(0.5)
# Out:
# np.float64(-0.6931471805599453)

# %% [markdown]
# ---
# ## 10. Finding capture time using lyaponov

# %%
def moving_average(x, window):
    return np.convolve(x, np.ones(window) / window, mode="same")

def find_t_star_lyp(L, a_val, show_samples, threshold=1/10, show=True, skip_init=7, window_size=20):
    t_stars = []

    if show:
        ax = plt.gca() 

        color = ax._get_lines.get_next_color()

        ys = np.array(collected_lambda_mean[L][a_val])
        ts = np.array([i*time_steps for i in range(len(ys))])
        y_errs = np.array(collected_lambda_errs[L][a_val])

        ax.plot(ts, ys, c="k", linewidth=5, alpha=0.1, label="Ensamble Avg")
        ax.fill_between(ts, ys+y_errs, ys-y_errs, color="k", alpha=0.1)

        ax.axhline(np.log(a_val), label="ln(a)")

        ax.set_xlabel("t")
        ax.set_ylabel("lambda")
        ax.set_title(f"L = {L} : a = {a_val}")

    for sample, sample_data in enumerate(collected_lambda[L][a_val]):
        avged_sample_data = moving_average(sample_data, window_size)

        t_stars.append((np.argmax((np.abs((avged_sample_data[skip_init:] - np.log(a_val))/np.log(a_val)) <= threshold)) + skip_init)*time_steps)
        
        if show and (-1 in show_samples or sample in show_samples):
            color = ax._get_lines.get_next_color()
        
            ax.plot(ts, sample_data, c=color, alpha=0.2)
            ax.plot(ts, avged_sample_data, c=color, alpha=0.5)

            ax.axvline(t_stars[sample], c=color, alpha=0.5)

    if show:
        ys = np.array(collected_lambda_mean[L][a_val])
        ts = np.array([i*time_steps for i in range(len(ys))])
        # x_lims = [0, max(t_stars)+30]
        # ax.set_xlim(x_lims[0], x_lims[1])

        # mask = (ts >= x_lims[0]) & (ts <= x_lims[1])
        # ax.set_ylim(ys[mask].min(), ys[mask].max())

        plt.legend()
        plt.show()
    return t_stars

find_t_star_lyp(32, 0.62, [150, 20], show=True, skip_init=0, threshold=0.05, window_size=35)
# Out:
# [np.int64(43),
#  np.int64(31),
#  np.int64(35),
#  np.int64(39),
#  np.int64(48),
#  np.int64(34),
#  np.int64(42),
#  np.int64(28),
#  np.int64(42),
#  np.int64(26),
#  np.int64(30),
#  np.int64(44),
#  np.int64(33),
#  np.int64(51),
#  np.int64(28),
#  np.int64(41),
#  np.int64(30),
#  np.int64(43),
#  np.int64(38),
#  np.int64(38),
#  np.int64(49),
#  np.int64(51),
#  np.int64(34),
#  np.int64(68),
#  np.int64(36),
#  np.int64(48),
#  np.int64(42),
#  np.int64(52),
#  np.int64(54),
#  np.int64(60),
#  np.int64(36),
#  np.int64(34),
#  np.int64(29),
#  np.int64(31),
#  np.int64(27),
#  np.int64(36),
#  np.int64(29),
#  np.int64(37),
#  np.int64(46),
#  np.int64(33),
#  np.int64(34),
#  np.int64(38),
#  np.int64(43),
#  np.int64(36),
#  np.int64(47),
#  np.int64(40),
#  np.int64(34),
#  np.int64(49),
#  np.int64(29),
#  np.int64(45),
#  np.int64(30),
#  np.int64(28),
#  np.int64(17),
#  np.int64(48),
#  np.int64(57),
#  np.int64(41),
#  np.int64(45),
#  np.int64(33),
# ...

# %%
a_vals = [0.58, 0.6, 0.62]

for L_val in np.array(num_unit_cells_vals) * N_val:
    fig, axs = plt.subplots(
        1, len(a_vals),
        figsize=(4 * len(a_vals), 4)
    )

    # Handles the case where there is only one a_val
    axs = np.atleast_1d(axs)

    for ax, a_val in zip(axs, a_vals):

        t_stars = np.array(
            find_t_star_lyp(L_val, a_val, [], show=False, skip_init=0, threshold=0.05, window_size=35)
            # find_t_star_dist(L_val, a_val, [], show=False)
        )

        # Poisson fit
        lam = np.mean(t_stars)
        lam = poisson_fit(t_stars)

        xs = np.arange(0, t_stars.max() + 1)
        pmf = poisson.pmf(xs, lam)

        bins = np.arange(-0.5, t_stars.max() + 1.5, 1)

        ax.hist(
            t_stars,
            bins=bins,
            alpha=0.3,
            density=True
        )

        ax.plot(
            xs,
            pmf,
            "--",
            label=fr"$\mu={lam:.3f}$",
        )
        # ax.set_title(rf"a = {a_val}")

        ax.text(0.65, 0.7, rf"a = {a_val}", transform=ax.transAxes,
                ha="left",
                va="top")

        ax.legend(fontsize=14)
        ax.set_xlabel("Capture Time")
    axs[0].set_ylabel("Probability")
    axs[0].text(0.05, 0.95, rf"L = {L_val}", transform=axs[0].transAxes,
                ha="left",
                va="top", fontsize=20)
    # fig.suptitle(fr"$L={L_val}$")

    plt.tight_layout()

    plt.savefig(f"figs/capture_time/L{L_val}.pdf")
    plt.show()

# %% [markdown]
# ### 10a. Define Fitting Windows

# %%
# times_to_fit[z][L][a_val] = [t_min, t_max]  (1-indexed, inclusive)
# Only the z=1.7 windows are shown — add z=1.6 and z=1.65 dicts in the same style if needed.

times_to_fit = {}

times_to_fit[1.7] = {
    512: {
        0.68: [5, 100], 0.70: [5, 150], 0.71: [5, 160],
        0.72: [20, 300], 0.73: [40, 410], 0.74: [60, 900],
        0.75: [80, 3150], 0.7525: [175, 4350], 0.755: [80, 12500],
        0.7563: [400, 30000],
        **{a: [400, int(round(512**1.7))] for a in
           [0.7575, 0.7588, 0.7594, 0.76, 0.7605]},
        **{a: [600, int(round(512**1.7))] for a in
           [0.761, 0.7615, 0.7616, 0.7617, 0.7618, 0.7619,
            0.762, 0.7625, 0.763, 0.765, 0.7675, 0.77, 0.78, 0.79, 0.8]},
    },
    256: {
        0.67: [5, 70], 0.68: [5, 80], 0.69: [5, 100], 0.7: [5, 120],
        0.71: [10, 200], 0.72: [10, 325], 0.73: [100, 650],
        0.74: [200, 1400], 0.75: [200, 3500], 0.7525: [400, 5200],
        0.755: [300, 6500], 0.7563: [300, 10000],
        **{a: [200, int(round(256**1.7))] for a in [0.7575, 0.7588, 0.7594, 0.76, 0.7605]},
        **{a: [500, int(round(256**1.7))] for a in [0.761, 0.7615]},
        **{a: [600, int(round(512**1.7))] for a in
           [0.7616, 0.7617, 0.7618, 0.7619, 0.762, 0.7625, 0.763,
            0.765, 0.7675, 0.77, 0.78, 0.79, 0.8]},
    },
    128: {
        0.67: [5, 60], 0.68: [5, 84], 0.69: [5, 96], 0.7: [5, 120],
        0.71: [5, 180], 0.72: [5, 250], 0.73: [5, 500],
        0.74: [300, 1000], 0.75: [150, 2000],
        0.7525: [150, int(round(128**1.67))],
        0.755:  [150, int(round(128**1.68))],
        0.7563: [150, int(round(128**1.68))],
        0.7575: [150, int(round(128**1.69))],
        0.7588: [150, int(round(128**1.69))],
        0.7594: [100, int(round(128**1.69))],
        0.76:   [100, int(round(128**1.7))],
        0.7605: [150,   int(round(128**1.7))],
        **{a: [500, int(round(128**1.7))] for a in [0.761, 0.7615, 0.762, 0.7625]},
        0.763: [700, int(round(128**1.7))],
    },
    64: {
        0.67: [1, 65], 0.68: [1, 90], 0.69: [1, 100], 0.7: [1, 140],
        0.71: [1, 220], 0.72: [1, 280], 0.73: [1, 340], 0.74: [1, 600],
        **{a: [10, int(round(64**1.67))]  for a in [0.75, 0.7525, 0.755]},
        **{a: [100, int(round(64**1.7))]  for a in [0.7563, 0.7575, 0.7588, 0.7594, 0.76, 0.7605]},
        **{a: [500, int(round(64**1.7))]  for a in [0.761, 0.7615, 0.762, 0.7625, 0.763]},
    },
    32: {
        0.67: [1, 60], 0.68: [1, 70], 0.69: [1, 90], 0.7: [1, 120],
        0.71: [1, 168], 0.72: [1, 240], 0.73: [1, 300],
        **{a: [10, int(round(32**1.7))]  for a in [0.74, 0.75, 0.7525, 0.755, 0.7563]},
        **{a: [40, int(round(32**1.7))]  for a in [0.7575, 0.7588, 0.7594, 0.76]},
        0.7605: [50, int(round(32**1.7))],
        **{a: [100, int(round(32**1.7))] for a in [0.761, 0.7615, 0.762, 0.7625, 0.763]},
    },
}

# %% [markdown]
# ### 10b. Compute Slopes (Fits)

# %%
z_fit_val  = 1.7
decay_a_vals = [a for a in a_vals if 0.68 <= a <= 0.7615]

all_log_s_diff_slopes     = {}   # {L: {a: slope}}
all_log_s_diff_offsets    = {}   # {L: {a: intercept}}
all_log_s_diff_slope_errs = {}   # {L: {a: slope_stderr}}

for L in [n * N_val for n in num_unit_cells_vals]:
    all_log_s_diff_slopes[L]     = {}
    all_log_s_diff_offsets[L]    = {}
    all_log_s_diff_slope_errs[L] = {}

    for a_val in decay_a_vals:
        t_min, t_max = times_to_fit[z_fit_val][L][a_val]   # 1-indexed
        log_s = np.log(collected_S_diffs_mean[L][a_val][t_min - 1 : t_max])
        xs    = np.arange(1, len(log_s) + 1, dtype=float)

        slope, intercept, _, _, stderr = linregress(xs, log_s)
        all_log_s_diff_slopes[L][a_val]     = slope
        all_log_s_diff_offsets[L][a_val]    = intercept
        all_log_s_diff_slope_errs[L][a_val] = stderr

    print(f"Fits done for L={L}")
# Out:
# Fits done for L=32
# Fits done for L=64
# Fits done for L=128
# Fits done for L=256
# Fits done for L=512

# %% [markdown]
# ### 10c. Verify Fits Visually

# %%
fitted_a_vals_to_plot = [a for a in a_vals if 0.67 <= a <= 0.7615]

for L in [n * N_val for n in num_unit_cells_vals]:
    fig, ax = plt.subplots(figsize=(8, 5))
    ax.set_title(f"log(S_diff) fits | L={L}")
    ax.set_xlabel(r"$t$")
    ax.set_ylabel(r"$\log(S_{\mathrm{diff}})$")

    for i, a_val in enumerate(fitted_a_vals_to_plot):
        t_min, t_max = times_to_fit[z_fit_val][L][a_val]
        log_s = np.log(collected_S_diffs_mean[L][a_val][t_min - 1 : t_max])
        xs    = np.arange(1, len(log_s) + 1)
        c     = plt.cm.tab20(i / len(fitted_a_vals_to_plot))

        ax.plot(log_s,  color=c, linewidth=1, label=f"a={a_val}")
        ax.plot(xs, all_log_s_diff_offsets[L][a_val] + all_log_s_diff_slopes[L][a_val] * xs,
                color=c, linewidth=2, linestyle="--")

    ax.legend(fontsize=8)
    fig.tight_layout()
    plt.show()
# Out:
# /var/folders/0k/n4x5z88x1rx124p1g1l55hmc0000gn/T/ipykernel_15399/922984708.py:19: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(fontsize=8)
