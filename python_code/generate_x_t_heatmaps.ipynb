# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# a_vals = [round(0.5 + i*0.1, digits = 2) for i in 0:5] 
a_val = 0.72
a_val_name = f"{a_val}".replace(".", "p")

gloabl_L = 64
N_val = 4
z_val = 1
L_val = gloabl_L * N_val

# %%
# load the data
# Out:
# '0p7'
